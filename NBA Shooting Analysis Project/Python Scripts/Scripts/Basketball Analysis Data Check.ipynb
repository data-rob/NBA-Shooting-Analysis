# %% [markdown]
# # Basketball Analysis Data Cleaning

# %%
#Importing libraries

import os
import numpy as np
import pandas as pd
import matplotlib
from matplotlib import pyplot as plt

# %%
#Loading dataset

path = r'C:\Users\rmr1q.000\Desktop\CareerFoundry\Section 6'
data = pd.read_csv(os.path.join(path, 'Basketball Data 2020-2023 CSV.csv'), encoding='latin-1')

# %%
data.shape
# Out:
# (2213, 32)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2213 entries, 0 to 2212
# Data columns (total 32 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Pts Rnk            2213 non-null   int64
#  1   Player             2213 non-null   object
#  2   Season             2213 non-null   int64
#  3   Pos                2213 non-null   object
#  4   Age                2213 non-null   int64
#  5   Tm                 2213 non-null   object
#  6   G                  2213 non-null   int64
#  7   GS                 2213 non-null   int64
#  8   MP                 2213 non-null   int64
#  9   FG                 2213 non-null   int64
#  10  FGA                2213 non-null   int64
#  11  FG%                2199 non-null   float64
#  12  3P                 2213 non-null   int64
#  13  3PA                2213 non-null   int64
#  14  3P%                2107 non-null   float64
#  15  2P                 2213 non-null   int64
# ...

# %%
data.count().plot(kind='bar', figsize=(14,8))
# Out:
# <Axes: >

# %% [markdown]
# The only columns that have missing values are columns that track a percentage. It is very likely the reason these values are missing is because there has not been any data recorded by certain players for certain statistics so they do not have a percentage value yet. For example, a player with 0 3 point attempts will have a missing value for their 3 point percentage. These missing values should be left as is.

# %%
non_null
# Out:
# Pts Rnk              2213
# Player               2213
# Season               2213
# Pos                  2213
# Age                  2213
# Tm                   2213
# G                    2213
# GS                   2213
# MP                   2213
# FG                   2213
# FGA                  2213
# FG%                  2199
# 3P                   2213
# 3PA                  2213
# 3P%                  2107
# 2P                   2213
# 2PA                  2213
# 2P%                  2184
# eFG%                 2199
# FT                   2213
# FTA                  2213
# FT%                  2087
# ORB                  2213
# DRB                  2213
# TRB                  2213
# AST                  2213
# STL                  2213
# BLK                  2213
# TOV                  2213
# PF                   2213
# PTS?                 2213
# Player-additional    2213
# dtype: int64

# %%
data.describe()
# Out:
#            Pts Rnk       Season          Age            G           GS  \
# count  2213.000000  2213.000000  2213.000000  2213.000000  2213.000000
# mean    277.948486  2021.521464    25.652508    44.003615    20.781744
# std     161.219255     1.102404     4.157706    23.703411    25.208835
# min       1.000000  2020.000000    19.000000     1.000000     0.000000
# 25%     139.000000  2021.000000    22.000000    24.000000     1.000000
# 50%     277.000000  2022.000000    25.000000    49.000000     7.000000
# 75%     415.000000  2022.000000    28.000000    64.000000    39.000000
# max     605.000000  2023.000000    43.000000    83.000000    83.000000
#
#                 MP           FG          FGA          FG%           3P  ...  \
# count  2213.000000  2213.000000  2213.000000  2199.000000  2213.000000  ...
# mean   1004.128784   171.152282   367.392680     0.449186    51.624944  ...
# std     769.848351   162.742435   342.261223     0.114621    57.908119  ...
# ...
